# %%
import pandas as pd 
import numpy as np
import sys
import seaborn as sns
import os
import matplotlib.pyplot as plt
from IPython import display

# %%
 df1 = (
           
          pd.read_csv('/Users/dhairyab019/project-group12-project/data/raw/PS4_GamesSales.csv',encoding = 'latin')
          .dropna().reset_index(drop = True)
          .drop(columns='Year')
            
      )
df1
# Out:
#                           Game             Genre                   Publisher  \
# 0           Grand Theft Auto V            Action              Rockstar Games
# 1    Call of Duty: Black Ops 3           Shooter                  Activision
# 2        Red Dead Redemption 2  Action-Adventure              Rockstar Games
# 3           Call of Duty: WWII           Shooter                  Activision
# 4                      FIFA 18            Sports                   EA Sports
# ..                         ...               ...                         ...
# 820                  Biomutant            Action                  THQ Nordic
# 821                    de Blob          Platform                  THQ Nordic
# 822           Chaos on Deponia         Adventure      Daedalic Entertainment
# 823                  Code Vein            Action  Bandai Namco Entertainment
# 824   Radial G Racing Revolved            Racing               Tammeka Games
#
# ...

# %%
 df2 = (
           
          pd.read_csv('/Users/dhairyab019/project-group12-project/data/raw/XboxOne_GameSales.csv',encoding = 'latin')
          .dropna().reset_index(drop = True)
          .drop(columns='Year')
            
      )
df2
# Out:
#      Pos                       Game             Genre  \
# 0      1         Grand Theft Auto V            Action
# 1      2  Call of Duty: Black Ops 3           Shooter
# 2      3         Call of Duty: WWII           Shooter
# 3      4      Red Dead Redemption 2  Action-Adventure
# 4      5                  MineCraft              Misc
# ..   ...                        ...               ...
# 500  609                  Biomutant            Action
# 501  610                  Biomutant            Action
# 502  611                    de Blob          Platform
# 503  612    Outcast: Second Contact         Adventure
# 504  613                  Code Vein            Action
#
#                       Publisher  North America  Europe  Japan  Rest of World  \
# 0                Rockstar Games           4.70    3.25   0.01           0.76
# 1                    Activision           4.63    2.04   0.02           0.68
# 2                    Activision           3.75    1.91   0.00           0.57
# ...
